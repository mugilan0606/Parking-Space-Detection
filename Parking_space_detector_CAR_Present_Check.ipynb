# %% [markdown]
# <a href="https://colab.research.google.com/github/mugilan0606/Parking-Space-Detection/blob/main/Parking_space_detector_CAR_Present_Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
img1=cv2.imread("/content/car7.JPG")
plt.imshow(img1)

# %%
img2=cv2.imread("/content/car7.JPG")
gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
pts=[]
for apperturesize in [3,7]:
  edges=cv2.Canny(gray,50,100,apertureSize=apperturesize)
  lines=cv2.HoughLines(edges,1,np.pi/180,100)
  for rho,theta in lines[0]:
    a=np.cos(theta)
    b=np.sin(theta)
    x0=a*rho
    y0=b*rho
    x1=int(x0+1000*(-b))
    y1=int(y0+1000*(a))
    x2=int(x0-1000*(-b))
    y2=int(y0-1000*(a))
    cv2.line(img2,(x1,y1),(x2,y2),(255,0,0),2)
    pts.append(x1)

print(pts)
# Out:
# [108, 92]

# %%
plt.imshow(img2)

# %%
blur=cv2.bilateralFilter(img1,5,10,10)
plt.imshow(blur)

# %%
edges=cv2.Canny(blur,150,200)
plt.imshow(edges)

# %%
arr=[]
for i in range(edges.shape[1]):
  for j in range(edges.shape[0]):
    if edges[j][i]!=0:
      arr.append(i)

# %%
if len(arr)>2000:
  print("parking occupied")
else:
  print("parking available")
plt.imshow(img2)
# Out:
# parking occupied
